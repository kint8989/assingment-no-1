# %%
 Q1.Explain with an example each when to use a for loop and a while loop.
 
'''ANS= 1) While ioop is used to run a block code untill a certain condition is met . while condition first evalulates the condition 
if is true the while loop get excuted and this process contineus untill the condition is false and when condition becomes false
the loop stops.'''
  EX i = 39
     n = 46
        while i <= n:
            print(i)
            i=i+1
            
    '''2) for loop can iterate over every item in a list and go through every single charcter in a string and won't stop untill it has gone through
    all charcter .'''
   EX language =['marathi','hindi','english'] 
            for l in language:
               print(language)

Q2. Write a python program to print the sum and product of the first 10 natural numbers using for and while loop.

ANS= #using while loop
    
num=int(input("enter the positive number"))
if num < 0:
    print("enter positive number")
else:
    sum=0
    while(num>0):
        sum += num
        num -= 1
        print("the result",sum)
        
      #using for loop
 num = int(input("enter the number:"))
sum = 0
for v in range(1,num+1):
    sum = sum + value
    print(sum)
    
Q3. Create a python program to compute the electricity bill for a household.The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
You are required to take the units of electricity consumed in a month from the user as input.
Your program must pass this test case: when the unit of electricity consumed by the user in a month is
310, the total electricity bill should be 2250.

ans=
units = int(input("enter no of units you have consumed : "))
if(units < 100):
    amount = units * 6
elif(units <= 200):
    amount = 100*6 + (units - 200)*10))
else(units <=300):
    amount= 100*6+100*10 +  (units -300)* 20))

    total = amount 
print("electric bill =%.2f" ,%total)
    
Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
that list.

ans=
numbers = list(range(1, 101))
result = []

for number in numbers:
    cube = number ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        result.append(number)

        print("Using for loop:")
print("Numbers whose cube is divisible by 4 or 5:", result)

result.clear()
i = 1
while i <= 100:
    cube = i ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        result.append(i)
    i += 1
print("\nUsing while loop:")
print("Numbers whose cube is divisible by 4 or 5:", result)

Q5. Write a program to filter count vowels in the below-given string.
string = "I want to become a data scientist"
string = "I want to become a data scientist"
def count_vowels(s):
    vowels = "aeiouAEIOU"
    count = 0
    for char in s:
        if char in vowels:
            count += 1
    return count

# call the count_vowels function on the string
num_vowels = count_vowels(string)

# print the number of vowels in the string
print("The number of vowels in the string is:", num_vowels)

# %%
+
